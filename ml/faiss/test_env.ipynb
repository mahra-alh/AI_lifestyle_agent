# %%
from semantic_search import FAISSRetriever

retriever = FAISSRetriever()

results = retriever.search(
    "quiet cafe to study",
    k=5
)

print(results)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
#              venue_id                                  faiss_text  \
# 1683  ta_7309e4367ac8                  the lobby cafe cafe medium
# 6402  ta_1fd70bac73dc                      cafe fresh cafe medium
# 2213  ta_7e0c9549906c                amongst few cafe cafe medium
# 6828  ta_db21bb3b097f                        business cafe medium
# 2612  ta_72fd7fc154a2  the kitchen cafe cafe international medium
#
#       similarity_score
# 1683          0.622533
# 6402          0.611922
# 2213          0.610294
# 6828          0.607747
# 2612          0.606965
